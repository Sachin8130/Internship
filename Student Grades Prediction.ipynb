# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Student_Grades.csv')

# %%
df
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 0    CS-97001     B-     D+     C-         C     C-     D+      D     C-
# 1    CS-97002      A      D     D+         D     B-      C      D      A
# 2    CS-97003      A      B      A        B-     B+      A     B-     B+
# 3    CS-97004      D     C+     D+         D      D     A-     D+     C-
# 4    CS-97005     A-     A-     A-        B+      A      A     A-     B+
# ..        ...    ...    ...    ...       ...    ...    ...    ...    ...
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# ...

# %%
df.shape
# Out:
# (571, 43)

# %%
df.columns
# Out:
# Index(['Seat No.', 'PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111',
#        'CS-105', 'CS-106', 'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20',
#        'MT-222', 'EE-222', 'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214',
#        'EE-217', 'CS-212', 'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301',
#        'CS-302', 'TC-383', 'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312',
#        'CS-317', 'CS-403', 'CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423',
#        'CS-412', 'CGPA'],
#       dtype='object')

# %%
col_null=df.columns[df.isnull().any()].tolist()

# %%
df[col_null]
# Out:
#     CY-105 HS-105/12 MT-111 CS-106 EL-102 EE-119 ME-107 CS-107 HS-205/20  \
# 0       C-         C     C-      D     C-     B-     C-     C-        B+
# 1       D+         D     B-      D      A     D+      D     B+        C+
# 2        A        B-     B+     B-     B+     A-     A-     B-        A-
# 3       D+         D      D     D+     C-      D     C+      D         B
# 4       A-        B+      A     A-     B+      A     A-      C         A
# ..     ...       ...    ...    ...    ...    ...    ...    ...       ...
# 566      A        A-     A+     A-     A-     A+     B+     A+         A
# 567      A         A      A      A     A-      A      A     A+        B+
# 568     A-        B+      A      A      A      A      B     A+        B-
# 569      D         A      D     B-     C-     B-     C-     A+        C+
# 570      D         C      C      B     C+      C     D+     B-        C+
#
#     MT-222  ... CS-306 CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419  \
# ...

# %%
df[col_null]
# Out:
#     CY-105 HS-105/12 MT-111 CS-106 EL-102 EE-119 ME-107 CS-107 HS-205/20  \
# 0       C-         C     C-      D     C-     B-     C-     C-        B+
# 1       D+         D     B-      D      A     D+      D     B+        C+
# 2        A        B-     B+     B-     B+     A-     A-     B-        A-
# 3       D+         D      D     D+     C-      D     C+      D         B
# 4       A-        B+      A     A-     B+      A     A-      C         A
# ..     ...       ...    ...    ...    ...    ...    ...    ...       ...
# 566      A        A-     A+     A-     A-     A+     B+     A+         A
# 567      A         A      A      A     A-      A      A     A+        B+
# 568     A-        B+      A      A      A      A      B     A+        B-
# 569      D         A      D     B-     C-     B-     C-     A+        C+
# 570      D         C      C      B     C+      C     D+     B-        C+
#
#     MT-222  ... CS-306 CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419  \
# ...

# %%
from sklearn.impute import SimpleImputer
si=SimpleImputer(strategy="most_frequent")
df[col_null]=pd.DataFrame(si.fit_transform(df[col_null]),columns=df[col_null].columns)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
for i in col_null:
    print(i,df[i].unique())
# Out:
# CY-105 ['C-' 'D+' 'A' 'A-' 'B' 'C+' 'B+' 'B-' 'C' 'D' 'WU' 'A+' 'F']
# HS-105/12 ['C' 'D' 'B-' 'B+' 'D+' 'B' 'C-' 'C+' 'A-' 'A' 'WU' 'A+' 'F']
# MT-111 ['C-' 'B-' 'B+' 'D' 'A' 'C+' 'A-' 'C' 'B' 'D+' 'A+' 'F' 'WU']
# CS-106 ['D' 'B-' 'D+' 'A-' 'C+' 'A' 'C-' 'C' 'B' 'B+' 'A+' 'F' 'WU']
# EL-102 ['C-' 'A' 'B+' 'B' 'A-' 'B-' 'C' 'C+' 'D+' 'D' 'A+' 'WU' 'F']
# EE-119 ['B-' 'D+' 'A-' 'D' 'A' 'B+' 'B' 'C-' 'C+' 'C' 'WU' 'A+']
# ME-107 ['C-' 'D' 'A-' 'C+' 'B+' 'A' 'D+' 'C' 'B' 'B-' 'WU' 'F' 'A+']
# CS-107 ['C-' 'B+' 'B-' 'D' 'C' 'A-' 'C+' 'D+' 'B' 'A' 'A+' 'I' 'WU' 'F']
# HS-205/20 ['B+' 'C+' 'A-' 'B' 'A' 'B-' 'D' 'WU' 'A+' 'C' 'D+' 'C-' 'F']
# MT-222 ['D' 'B-' 'A' 'D+' 'C' 'B+' 'A-' 'B' 'C+' 'C-' 'WU' 'F' 'A+' 'W']
# EE-222 ['A-' 'C-' 'A' 'B-' 'B+' 'C+' 'D+' 'B' 'C' 'W' 'A+' 'D' 'F']
# MT-224 ['B-' 'D+' 'A' 'D' 'A-' 'C-' 'C' 'B+' 'C+' 'B' 'A+' 'WU' 'W' 'F']
# CS-210 ['C+' 'D+' 'A' 'C' 'A-' 'B+' 'B-' 'B' 'D' 'A+' 'C-' 'WU' 'W' 'F']
# ...

# %%
df.drop('Seat No.',axis=1,inplace=True)

# %%
df
# Out:
#     PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119 ME-107  \
# 0       B-     D+     C-         C     C-     D+      D     C-     B-     C-
# 1        A      D     D+         D     B-      C      D      A     D+      D
# 2        A      B      A        B-     B+      A     B-     B+     A-     A-
# 3        D     C+     D+         D      D     A-     D+     C-      D     C+
# 4       A-     A-     A-        B+      A      A     A-     B+      A     A-
# ..     ...    ...    ...       ...    ...    ...    ...    ...    ...    ...
# 566      B      A      A        A-     A+      A     A-     A-     A+     B+
# 567     A+      A      A         A      A      A      A     A-      A      A
# 568      B      A     A-        B+      A      A      A      A      A      B
# 569      A     B+      D         A      D     D+     B-     C-     B-     C-
# 570      C      D      D         C      C     D+      B     C+      C     D+
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=le.fit_transform(df[i])

# %%
df
# Out:
#      PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  EL-102  \
# 0         5      10       8          6       8      10       9       8
# 1         0       9      10          9       5       6       9       0
# 2         0       3       0          5       4       0       5       4
# 3         9       7      10          9       9       2      10       8
# 4         2       2       2          4       0       0       2       4
# ..      ...     ...     ...        ...     ...     ...     ...     ...
# 566       3       0       0          2       1       0       2       2
# 567       1       0       0          0       0       0       0       2
# 568       3       0       2          4       0       0       0       0
# 569       0       4       9          0       9      10       5       8
# 570       6       9       9          6       6      10       3       7
#
#      EE-119  ME-107  ...  CS-312  CS-317  CS-403  CS-421  CS-406  CS-414  \
# ...

# %%
x=df.drop('CGPA',axis=1)

# %%
x
# Out:
#      PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  EL-102  \
# 0         5      10       8          6       8      10       9       8
# 1         0       9      10          9       5       6       9       0
# 2         0       3       0          5       4       0       5       4
# 3         9       7      10          9       9       2      10       8
# 4         2       2       2          4       0       0       2       4
# ..      ...     ...     ...        ...     ...     ...     ...     ...
# 566       3       0       0          2       1       0       2       2
# 567       1       0       0          0       0       0       0       2
# 568       3       0       2          4       0       0       0       0
# 569       0       4       9          0       9      10       5       8
# 570       6       9       9          6       6      10       3       7
#
#      EE-119  ME-107  ...  CS-306  CS-312  CS-317  CS-403  CS-421  CS-406  \
# ...

# %%
y=df['CGPA']

# %%
y
# Out:
# 0      2.205
# 1      2.008
# 2      3.608
# 3      1.906
# 4      3.448
#        ...
# 566    3.798
# 567    3.772
# 568    3.470
# 569    2.193
# 570    1.753
# Name: CGPA, Length: 571, dtype: float64

# %%
x.value_counts()
# Out:
# PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  EL-102  EE-119  ME-107  CS-107  HS-205/20  MT-222  EE-222  MT-224  CS-210  CS-211  CS-203  CS-214  EE-217  CS-212  CS-215  MT-331  EF-303  HS-304  CS-301  CS-302  TC-383  MT-442  EL-332  CS-318  CS-306  CS-312  CS-317  CS-403  CS-421  CS-406  CS-414  CS-419  CS-423  CS-412
# 0       0       0       0          7       0       4       6       4       4       7       4          0       5       4       2       5       7       7       6       2       3       4       1       5       2       0       4       2       5       6       3       3       3       3       3       5       2       0       7       3         1
# ...

# %%
y.value_counts()
# Out:
# 3.019    5
# 3.058    3
# 2.793    3
# 3.443    3
# 2.206    3
#         ..
# 2.555    1
# 2.042    1
# 2.634    1
# 2.053    1
# 1.753    1
# Name: CGPA, Length: 491, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression

# %%
MaxAcc=0
MaxRS=0
for i in range(0,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred=lr.predict(x_test,)
    acc=r2_score(y_test,pred)
    if acc>MaxAcc:
        MaxAcc=acc
        MaxRS=i
print("Maximum R2 Score=",MaxAcc,"Maximum Random State=",MaxRS)
# Out:
# Maximum R2 Score= 0.9643494726169242 Maximum Random State= 72

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=MaxRS)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import Lasso,Ridge
from sklearn.svm import SVR

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
predLR=lr.predict(x_test)
predLR_train=lr.predict(x_train)
print("r2 score:",r2_score(y_test,predLR))
print("r2 score on train data:",r2_score(y_train,predLR_train))
print("Mean Absolute Error:",mean_absolute_error(y_test,predLR))
print("Mean_square_error",mean_squared_error(y_test,predLR))
print("RMSE:",np.sqrt(mean_squared_error(y_test,predLR)))
# Out:
# r2 score: 0.9643494726169242
# r2 score on train data: 0.9139022616556756
# Mean Absolute Error: 0.0893834077440855
# Mean_square_error 0.013741931476875207
# RMSE: 0.1172259846487766

# %%
GBR=GradientBoostingRegressor()
GBR.fit(x_train,y_train)
predGBR=GBR.predict(x_test)
predGBR_train=GBR.predict(x_train)
print("R2 Score:",r2_score(y_test,predGBR))
print("R2 score on train data=",r2_score(y_train,predGBR_train))
print("Mean Absolute Error:",mean_absolute_error(y_test,predGBR))
print("Mean Squared Error:",mean_squared_error(y_test,predGBR))
print("RMSE:",np.sqrt(mean_squared_error(y_test,predGBR)))
# Out:
# R2 Score: 0.9670248292429691
# R2 score on train data= 0.9953002375042729
# Mean Absolute Error: 0.08273671984182417
# Mean Squared Error: 0.012710682568934366
# RMSE: 0.1127416629686398

# %%
DTR=DecisionTreeRegressor()
DTR.fit(x_train,y_train)
predDTR=DTR.predict(x_test)
predDTR_train=DTR.predict(x_train)
print("R2 Score:",r2_score(y_test,predDTR))
print("R2 score on train data=",r2_score(y_train,predDTR_train))
print("Mean Absolute Error:",mean_absolute_error(y_test,predDTR))
print("Mean Squared Error:",mean_squared_error(y_test,predDTR))
print("RMSE:",np.sqrt(mean_squared_error(y_test,predDTR)))
# Out:
# R2 Score: 0.8217639102694178
# R2 score on train data= 1.0
# Mean Absolute Error: 0.19030232558139532
# Mean Squared Error: 0.06870327906976742
# RMSE: 0.2621131035827233

# %%
LA=Lasso()
LA.fit(x_train,y_train)
predLA=LA.predict(x_test)
predLA_train=LA.predict(x_train)
print("R2 Score:",r2_score(y_test,predLA))
print("R2 score on train data=",r2_score(y_train,predLA_train))
print("Mean Absolute Error:",mean_absolute_error(y_test,predLA))
print("Mean Squared Error:",mean_squared_error(y_test,predLA))
print("RMSE:",np.sqrt(mean_squared_error(y_test,predLA)))
# Out:
# R2 Score: 0.350609991970284
# R2 score on train data= 0.33484914041131697
# Mean Absolute Error: 0.4242155056363917
# Mean Squared Error: 0.2503153150084445
# RMSE: 0.50031521564754

# %%
RD=Ridge()
RD.fit(x_train,y_train)
predRD=RD.predict(x_test)
predRD_train=RD.predict(x_train)
print("r2 Score:",r2_score(y_test,predRD))
print("r2 score on train data:",r2_score(y_train,predRD_train))
print("MAE:",mean_absolute_error(y_test,predRD))
print("MSE:",mean_squared_error(y_test,predRD))
print("RMSE:",np.sqrt(mean_squared_error(y_test,predRD)))
# Out:
# r2 Score: 0.9643771003828862
# r2 score on train data: 0.9139022436130492
# MAE: 0.08935085255469426
# MSE: 0.013731282016836948
# RMSE: 0.11718055306592877

# %%
knn=KNN()
knn.fit(x_train,y_train)
predknn=knn.predict(x_test)
predknn_train=knn.predict(x_train)
print("R2 Score:",r2_score(y_test,predknn))
print("R2 score on train data=",r2_score(y_train,predknn_train))
print("Mean Absolute Error:",mean_absolute_error(y_test,predknn))
print("Mean Squared Error:",mean_squared_error(y_test,predknn))
print("RMSE:",np.sqrt(mean_squared_error(y_test,predknn)))
# Out:
# R2 Score: 0.9678399340351564
# R2 score on train data= 0.9142712169240712
# Mean Absolute Error: 0.08414302325581392
# Mean Squared Error: 0.012396490465116273
# RMSE: 0.11133952786461901

# %%
svr=SVR()
svr.fit(x_train,y_train)
predsvr=svr.predict(x_test)
predsvr_train=svr.predict(x_train)
print("R2 Score:",r2_score(y_test,predsvr))
print("R2 score on train data=",r2_score(y_train,predsvr_train))
print("Mean Absolute Error:",mean_absolute_error(y_test,predsvr))
print("Mean Squared Error:",mean_squared_error(y_test,predsvr))
print("RMSE:",np.sqrt(mean_squared_error(y_test,predsvr)))
# Out:
# R2 Score: 0.9729068281692774
# R2 score on train data= 0.9581722934535725
# Mean Absolute Error: 0.07778518158705636
# Mean Squared Error: 0.010443394196904394
# RMSE: 0.10219292635453979

# %%
from sklearn.model_selection import cross_val_score

# %%
scorelr=cross_val_score(lr,x,y,cv=5)
print(scorelr)
print(scorelr.mean())
print("Difference between r2 Score and cross val score:",r2_score(y_test,predLR)-(scorelr.mean()))
# Out:
# [0.8927601  0.93427094 0.90082619 0.94061762 0.84878197]
# 0.9034513625626616
# Difference between r2 Score and cross val score: 0.0608981100542626

# %%
scoreGBR=cross_val_score(GBR,x,y,cv=5)
print(scoreGBR)
print(scoreGBR.mean())
print("Difference Between r2 score and cross val score",r2_score(y_test,predGBR)-(scoreGBR.mean()))
# Out:
# [0.9200457  0.95816997 0.95345422 0.94561604 0.87508685]
# 0.9304745573251653
# Difference Between r2 score and cross val score 0.0365502719178038

# %%
scoreDTR=cross_val_score(DTR,x,y,cv=5)
print(scoreDTR)
print(scoreDTR.mean())
print("Difference Between r2 score and cross val score",r2_score(y_test,predDTR)-(scoreDTR.mean()))
# Out:
# [0.75534093 0.80893496 0.87055083 0.73810666 0.75281352]
# 0.7851493809865678
# Difference Between r2 score and cross val score 0.03661452928284992

# %%
scoreLA=cross_val_score(LA,x,y,cv=5)
print(scoreLA)
print(scoreLA.mean())
print("Difference Between r2 score and cross val score",r2_score(y_test,predLA)-(scoreLA.mean()))
# Out:
# [0.34542541 0.3341994  0.3340023  0.37377257 0.28984562]
# 0.33544905937176195
# Difference Between r2 score and cross val score 0.015160932598522026

# %%
scoreRD=cross_val_score(RD,x,y,cv=5)
print(scoreRD)
print(scoreRD.mean())
print("Difference Between r2 score and cross val score",r2_score(y_test,predRD)-(scoreRD.mean()))
# Out:
# [0.89277522 0.93427636 0.90085156 0.94066429 0.84879596]
# 0.9034726777742446
# Difference Between r2 score and cross val score 0.060904422608641595

# %%
scoresvr=cross_val_score(svr,x,y,cv=5)
print(scoresvr)
print(scoresvr.mean())
print("Difference Between r2 score and cross val score",r2_score(y_test,predsvr)-(scoresvr.mean()))
# Out:
# [0.89588569 0.92619817 0.91481769 0.94868905 0.85529357]
# 0.9081768357886064
# Difference Between r2 score and cross val score 0.06472999238067101

# %%
scoreknn=cross_val_score(knn,x,y,cv=5)
print(scoreknn)
print(scoreknn.mean())
print("Difference Between r2 score and cross val score",r2_score(y_test,predknn)-(scoreknn.mean()))
# Out:
# [0.88704165 0.93105804 0.86498494 0.95195617 0.81245731]
# 0.8894996210901137
# Difference Between r2 score and cross val score 0.07834031294504273

# %% [markdown]
# GBR is our best fit model because it has high accuracy and lowest difference between r2score and cross val score

# %% [markdown]
# Hyper parameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters={'learning_rate':[.1,0.01,0.001],
           'n_estimators':[1,5,10,23],
           'min_samples_split':[3,9,10,12],
            'max_depth':[3],
           'random_state':[2,7,10,14]}

# %%
gscv=GridSearchCV(GBR,parameters,cv=5)
gscv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingRegressor(),
#              param_grid={'learning_rate': [0.1, 0.01, 0.001], 'max_depth': [3],
#                          'min_samples_split': [3, 9, 10, 12],
#                          'n_estimators': [1, 5, 10, 23],
#                          'random_state': [2, 7, 10, 14]})

# %%
gscv.best_params_
# Out:
# {'learning_rate': 0.1,
#  'max_depth': 3,
#  'min_samples_split': 3,
#  'n_estimators': 23,
#  'random_state': 7}

# %%
Model=GradientBoostingRegressor(learning_rate=.1,max_depth=3,min_samples_split=3,n_estimators=23,random_state=7)

# %%
Model.fit(x_train,y_train)
predM=Model.predict(x_test)
print("R2 score:",r2_score(y_test,predM))
print("MAE:",mean_absolute_error(y_test,predM))
print("MSE:",mean_squared_error(y_test,predM))
print("RMSE:",np.sqrt(mean_squared_error(y_test,predM)))
# Out:
# R2 score: 0.9215362465118973
# MAE: 0.1383620283228541
# MSE: 0.030244812713873217
# RMSE: 0.17391035827078621

# %%
import joblib

# %%
joblib.dump(Model,'Students_grades.pkl')
# Out:
# ['Students_grades.pkl']

# %%
loaded_model=joblib.load('Students_grades.pkl')
y_pred=loaded_model.predict(x_test)
test_score=r2_score(y_test,y_pred)
print("Test R2 Score:",test_score*100)
# Out:
# Test R2 Score: 92.15362465118973

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],y_test[:]],index=["Predicted","Original"])
conclusion
# Out:
#                 0         1         2         3         4         5    \
# Predicted  2.192161  3.476505  3.190179  2.710532  2.840179  3.596778
# Original   2.288000  3.566000  3.114000  2.384000  2.311000  3.700000
#
#                 6         7         8         9    ...       162       163  \
# Predicted  3.236455  3.715019  3.290465  3.715019  ...  2.567772  2.646735
# Original   3.350000  3.943000  3.443000  3.908000  ...  2.564000  2.484000
#
#                 164       165       166       167       168       169     170  \
# Predicted  2.910832  2.806967  2.277206  2.207491  3.507931  2.880684  2.2656
# Original   2.917000  2.782000  2.321000  2.188000  3.554000  3.058000  2.0870
#
#                 171
# Predicted  3.520692
# Original   3.647000
#
# [2 rows x 172 columns]
