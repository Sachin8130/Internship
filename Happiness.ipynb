# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Happniess.csv')

# %%
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df.shape
# Out:
# (158, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df.nunique()
# Out:
# Country                          158
# Region                            10
# Happiness Rank                   157
# Happiness Score                  157
# Standard Error                   153
# Economy (GDP per Capita)         158
# Family                           158
# Health (Life Expectancy)         157
# Freedom                          158
# Trust (Government Corruption)    157
# Generosity                       158
# Dystopia Residual                158
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %% [markdown]
# There is no null value in all the columns
# Mean and 50% is nearly equal, Hence Skewness might not be present.
# There is a difference between 75 and Max in Happiness Rank, Hence Outliers might be present

# %% [markdown]
# Data Visualization

# %%
#Univariate Analysis

# %%
sns.distplot(df['Happiness Rank'])
# Out:
# <AxesSubplot:xlabel='Happiness Rank', ylabel='Density'>

# %%
sns.distplot(df['Happiness Score'])
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Density'>

# %%
sns.distplot(df['Standard Error'])
# Out:
# <AxesSubplot:xlabel='Standard Error', ylabel='Density'>

# %%
sns.distplot(df['Economy (GDP per Capita)'])
# Out:
# <AxesSubplot:xlabel='Economy (GDP per Capita)', ylabel='Density'>

# %%
sns.distplot(df['Family'])
# Out:
# <AxesSubplot:xlabel='Family', ylabel='Density'>

# %%
sns.distplot(df['Health (Life Expectancy)'])
# Out:
# <AxesSubplot:xlabel='Health (Life Expectancy)', ylabel='Density'>

# %%
sns.distplot(df['Freedom'])
# Out:
# <AxesSubplot:xlabel='Freedom', ylabel='Density'>

# %%
sns.distplot(df['Freedom'])
# Out:
# <AxesSubplot:xlabel='Freedom', ylabel='Density'>

# %%
sns.distplot(df['Trust (Government Corruption)'])
# Out:
# <AxesSubplot:xlabel='Trust (Government Corruption)', ylabel='Density'>

# %%
sns.distplot(df['Generosity'])
# Out:
# <AxesSubplot:xlabel='Generosity', ylabel='Density'>

# %%
sns.distplot(df['Dystopia Residual'])
# Out:
# <AxesSubplot:xlabel='Dystopia Residual', ylabel='Density'>

# %%
df['Happiness Rank'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 153    154
# 154    155
# 155    156
# 156    157
# 157    158
# Name: Happiness Rank, Length: 158, dtype: int64>

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
'''print(df['Happiness Score'].value_counts())
print(df['Standard Error'].value_counts())
print(df['Economy (GDP per Capita)'].value_counts())
print(df['Family'].value_counts())
print(df['Health (Life Expectancy)'].value_counts())
print(df['Freedom'].value_counts())
print(df['Trust (Goverment Corruption)'].value_counts())
print(df['Generosity'].value_counts())
print(df['Dystopia Residual'].value_counts())'''
# Out:
# "print(df['Happiness Score'].value_counts())\nprint(df['Standard Error'].value_counts())\nprint(df['Economy (GDP per Capita)'].value_counts())\nprint(df['Family'].value_counts())\nprint(df['Health (Life Expectancy)'].value_counts())\nprint(df['Freedom'].value_counts())\nprint(df['Trust (Goverment Corruption)'].value_counts())\nprint(df['Generosity'].value_counts())\nprint(df['Dystopia Residual'].value_counts())"

# %%
sns.countplot(x='Freedom',data=df)
# Out:
# <AxesSubplot:xlabel='Freedom', ylabel='count'>

# %%
sns.countplot(x='Happiness Rank',data=df)
# Out:
# <AxesSubplot:xlabel='Happiness Rank', ylabel='count'>

# %%
sns.countplot(x='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='count'>

# %%
sns.countplot(x='Economy (GDP per Capita)',data=df)
# Out:
# <AxesSubplot:xlabel='Economy (GDP per Capita)', ylabel='count'>

# %%
#Bivaraite Analysis

# %%
sns.boxplot(x='Country',y='Happiness Rank',data=df)
# Out:
# <AxesSubplot:xlabel='Country', ylabel='Happiness Rank'>

# %%
sns.boxplot(x='Trust (Government Corruption)',y='Happiness Rank',data=df)
# Out:
# <AxesSubplot:xlabel='Trust (Government Corruption)', ylabel='Happiness Rank'>

# %%
sns.scatterplot(x='Trust (Government Corruption)',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Trust (Government Corruption)', ylabel='Happiness Score'>

# %%
#Multivariate Analysis

# %%
plt.figure(figsize=(10,10))

df.plot(kind='kde',subplots=True,layout=(4,4))
# Out:
# array([[<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>]],
#       dtype=object)

# %%
plt.figure(figsize=(10,10))
df.plot(kind='box',layout=(3,4),subplots=True)
# Out:
# Happiness Rank                      AxesSubplot(0.125,0.653529;0.168478x0.226471)
# Happiness Score                  AxesSubplot(0.327174,0.653529;0.168478x0.226471)
# Standard Error                   AxesSubplot(0.529348,0.653529;0.168478x0.226471)
# Economy (GDP per Capita)         AxesSubplot(0.731522,0.653529;0.168478x0.226471)
# Family                              AxesSubplot(0.125,0.381765;0.168478x0.226471)
# Health (Life Expectancy)         AxesSubplot(0.327174,0.381765;0.168478x0.226471)
# Freedom                          AxesSubplot(0.529348,0.381765;0.168478x0.226471)
# Trust (Government Corruption)    AxesSubplot(0.731522,0.381765;0.168478x0.226471)
# Generosity                              AxesSubplot(0.125,0.11;0.168478x0.226471)
# Dystopia Residual                    AxesSubplot(0.327174,0.11;0.168478x0.226471)
# dtype: object

# %%
df.skew()
# Out:
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
from scipy.stats import boxcox

# %%
df['Standard Error']=boxcox(df['Standard Error'],0)

# %%
df.skew()
# Out:
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   0.484623
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
(df['Trust (Government Corruption)'])=boxcox(df['Trust (Government Corruption)'],0.5)

# %%
df.skew()
# Out:
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   0.484623
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    0.507663
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
(df['Generosity'])=boxcox(df['Generosity'],0.5)

# %%
df.skew()
# Out:
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   0.484623
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    0.507663
# Generosity                      -0.130961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
df['Family']=np.sqrt(df['Family'])

# %%
df.skew()
# Out:
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   0.484623
# Economy (GDP per Capita)        -0.317575
# Family                          -2.193070
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    0.507663
# Generosity                      -0.130961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
df['Health (Life Expectancy)']=np.sqrt(df['Health (Life Expectancy)'])

# %%
df.skew()
# Out:
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   0.484623
# Economy (GDP per Capita)        -0.317575
# Family                          -2.193070
# Health (Life Expectancy)        -1.380270
# Freedom                         -0.413462
# Trust (Government Corruption)    0.507663
# Generosity                      -0.130961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
df['Health (Life Expectancy)']=np.cbrt(df['Health (Life Expectancy)'])

# %%
df.skew()
# Out:
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   0.484623
# Economy (GDP per Capita)        -0.317575
# Family                          -2.193070
# Health (Life Expectancy)        -4.293928
# Freedom                         -0.413462
# Trust (Government Corruption)    0.507663
# Generosity                      -0.130961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
df['Family']=np.exp(df['Family'])

# %%
df.skew()
# Out:
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   0.484623
# Economy (GDP per Capita)        -0.317575
# Family                          -1.243904
# Health (Life Expectancy)        -4.293928
# Freedom                         -0.413462
# Trust (Government Corruption)    0.507663
# Generosity                      -0.130961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
df['Family']=np.exp(df['Family'])

# %%
df.skew()
# Out:
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   0.484623
# Economy (GDP per Capita)        -0.317575
# Family                          -0.208898
# Health (Life Expectancy)        -4.293928
# Freedom                         -0.413462
# Trust (Government Corruption)    0.507663
# Generosity                      -0.130961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
df['Health (Life Expectancy)']=np.exp(df['Health (Life Expectancy)'])

# %%
df.skew()
# Out:
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   0.484623
# Economy (GDP per Capita)        -0.317575
# Family                          -0.208898
# Health (Life Expectancy)        -2.661238
# Freedom                         -0.413462
# Trust (Government Corruption)    0.507663
# Generosity                      -0.130961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
df['Health (Life Expectancy)']=np.exp(df['Health (Life Expectancy)'])

# %%
df.skew()
# Out:
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   0.484623
# Economy (GDP per Capita)        -0.317575
# Family                          -0.208898
# Health (Life Expectancy)        -1.303203
# Freedom                         -0.413462
# Trust (Government Corruption)    0.507663
# Generosity                      -0.130961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
df['Health (Life Expectancy)']=np.exp(df['Health (Life Expectancy)'])

# %%
df.skew()
# Out:
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   0.484623
# Economy (GDP per Capita)        -0.317575
# Family                          -0.208898
# Health (Life Expectancy)         1.725024
# Freedom                         -0.413462
# Trust (Government Corruption)    0.507663
# Generosity                      -0.130961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
df['Health (Life Expectancy)']=np.random.exponential(df['Health (Life Expectancy)'])

# %%
df.skew()
# Out:
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   0.484623
# Economy (GDP per Capita)        -0.317575
# Family                          -0.208898
# Health (Life Expectancy)         5.133176
# Freedom                         -0.413462
# Trust (Government Corruption)    0.507663
# Generosity                      -0.130961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
df['Health (Life Expectancy)']=boxcox(df['Health (Life Expectancy)'],0.5)

# %%
df.skew()
# Out:
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   0.484623
# Economy (GDP per Capita)        -0.317575
# Family                          -0.208898
# Health (Life Expectancy)         1.997575
# Freedom                         -0.413462
# Trust (Government Corruption)    0.507663
# Generosity                      -0.130961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
df['Health (Life Expectancy)']=boxcox(df['Health (Life Expectancy)'],0.5)

# %%
df.skew()
# Out:
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   0.484623
# Economy (GDP per Capita)        -0.317575
# Family                          -0.208898
# Health (Life Expectancy)         0.615525
# Freedom                         -0.413462
# Trust (Government Corruption)    0.507663
# Generosity                      -0.130961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
#Now the skewness is remvoved from all the data

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(df[['Happiness Rank','Standard Error','Economy (GDP per Capita)','Family','Health (Life Expectancy)','Freedom','Trust (Government Corruption)','Generosity','Dystopia Residual']]))
z
# Out:
#      Happiness Rank  Standard Error  Economy (GDP per Capita)    Family  \
# 0          1.721000        0.915376                  1.369621  1.676294
# 1          1.699075        0.229364                  1.135226  2.037784
# 2          1.677149        0.993935                  1.192861  1.749940
# 3          1.655224        0.504531                  1.525130  1.555413
# 4          1.633299        0.785305                  1.194876  1.502132
# ..              ...             ...                       ...       ...
# 153        1.633576        0.866206                  1.552987  0.934601
# 154        1.655501        0.694170                  1.392303  1.918439
# 155        1.677427        0.313775                  0.455245  1.682106
# 156        1.699352        2.055159                  2.067566  1.801097
# 157        1.721277        1.250387                  1.586334  2.281763
#
#      Health (Life Expectancy)   Freedom  Trust (Government Corruption)  \
# ...

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([ 23,  63,  64, 101, 128, 155], dtype=int64), array([4, 7, 1, 7, 7, 8], dtype=int64))

# %%
z=np.array(z)

# %%
z[63][7]
# Out:
# 3.1817332720037563

# %%
df1=df[(z<3).all(axis=1)]

# %%
df1
# Out:
#          Country              Region  Happiness Rank  Happiness Score  \
# 0    Switzerland      Western Europe               1            7.587
# 1        Iceland      Western Europe               2            7.561
# 2        Denmark      Western Europe               3            7.527
# 3         Norway      Western Europe               4            7.522
# 4         Canada       North America               5            7.427
# ..           ...                 ...             ...              ...
# 152  Afghanistan       Southern Asia             153            3.575
# 153       Rwanda  Sub-Saharan Africa             154            3.465
# 154        Benin  Sub-Saharan Africa             155            3.340
# 156      Burundi  Sub-Saharan Africa             157            2.905
# 157         Togo  Sub-Saharan Africa             158            2.839
#
#      Standard Error  Economy (GDP per Capita)     Family  \
# 0         -3.378165                   1.39651  24.417743
# ...

# %%
df1.shape
# Out:
# (152, 12)

# %%
df.shape
# Out:
# (158, 12)

# %%
print("Data loss Percentage:",((df.shape[0]-df1.shape[0])/df.shape[0]))
# Out:
# Data loss Percentage: 0.0379746835443038

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in df1.columns:
    if df1[i].dtypes=='object':
        df1[i]=le.fit_transform(df1[i])

# %%
df1
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0        130       9               1            7.587       -3.378165
# 1         57       9               2            7.561       -3.019206
# 2         37       9               3            7.527       -3.402799
# 3        102       9               4            7.522       -3.249335
# 4         24       5               5            7.427       -3.337378
# ..       ...     ...             ...              ...             ...
# 152        0       7             153            3.575       -3.478943
# 153      114       8             154            3.465       -3.362746
# 154       13       8             155            3.340       -3.308801
# 156       21       8             157            2.905       -2.446686
# 157      135       8             158            2.839       -2.699041
#
#      Economy (GDP per Capita)     Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
df1_cor=df1.corr()

# %%
df1_cor
# Out:
#                                 Country    Region  Happiness Rank  \
# Country                        1.000000  0.018697       -0.107990
# Region                         0.018697  1.000000        0.216688
# Happiness Rank                -0.107990  0.216688        1.000000
# Happiness Score                0.095982 -0.181321       -0.992387
# Standard Error                 0.038079 -0.061601        0.200045
# Economy (GDP per Capita)       0.034956 -0.271154       -0.789096
# Family                         0.157162 -0.125963       -0.765973
# Health (Life Expectancy)      -0.045264 -0.231428       -0.588005
# Freedom                        0.094267  0.109522       -0.552351
# Trust (Government Corruption)  0.046046  0.206134       -0.343880
# Generosity                     0.113135  0.326170       -0.210509
# Dystopia Residual              0.010020 -0.056014       -0.509103
#
#                                Happiness Score  Standard Error  \
# ...

# %%
sns.heatmap(df1_cor,annot=True,cmap='Blues')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Separating Feature columns and Target Column

# %%
df1
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0        130       9               1            7.587       -3.378165
# 1         57       9               2            7.561       -3.019206
# 2         37       9               3            7.527       -3.402799
# 3        102       9               4            7.522       -3.249335
# 4         24       5               5            7.427       -3.337378
# ..       ...     ...             ...              ...             ...
# 152        0       7             153            3.575       -3.478943
# 153      114       8             154            3.465       -3.362746
# 154       13       8             155            3.340       -3.308801
# 156       21       8             157            2.905       -2.446686
# 157      135       8             158            2.839       -2.699041
#
#      Economy (GDP per Capita)     Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
x=df1.drop('Happiness Score',axis=1)

# %%
x
# Out:
#      Country  Region  Happiness Rank  Standard Error  \
# 0        130       9               1       -3.378165
# 1         57       9               2       -3.019206
# 2         37       9               3       -3.402799
# 3        102       9               4       -3.249335
# 4         24       5               5       -3.337378
# ..       ...     ...             ...             ...
# 152        0       7             153       -3.478943
# 153      114       8             154       -3.362746
# 154       13       8             155       -3.308801
# 156       21       8             157       -2.446686
# 157      135       8             158       -2.699041
#
#      Economy (GDP per Capita)     Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  24.417743                 64.266837  0.66557
# 1                     1.30232  26.257032                 80.848031  0.62877
# 2                     1.32548  24.792461                 95.924823  0.64938
# ...

# %%
y=df1['Happiness Score']

# %%
y
# Out:
# 0      7.587
# 1      7.561
# 2      7.527
# 3      7.522
# 4      7.427
#        ...
# 152    3.575
# 153    3.465
# 154    3.340
# 156    2.905
# 157    2.839
# Name: Happiness Score, Length: 152, dtype: float64

# %%
x.shape
# Out:
# (152, 11)

# %%
y.shape
# Out:
# (152,)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["VIF Values"]=[variance_inflation_factor(x.values,i)
                   for i in range(len(x.columns))]
vif["Features"]=x.columns
vif
# Out:
#     VIF Values                       Features
# 0     4.091166                        Country
# 1     5.904820                         Region
# 2    35.027159                 Happiness Rank
# 3   118.175210                 Standard Error
# 4    23.825144       Economy (GDP per Capita)
# 5    28.492221                         Family
# 6    11.008631       Health (Life Expectancy)
# 7    15.455431                        Freedom
# 8    32.684033  Trust (Government Corruption)
# 9    36.340781                     Generosity
# 10   35.319055              Dystopia Residual

# %%
#We need to scale the data first

# %%
from sklearn.preprocessing import StandardScaler
scale=StandardScaler()
x=pd.DataFrame(scale.fit_transform(x),columns=x.columns)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['Values']=[variance_inflation_factor(x.values,i)
              for i in range(len(x.columns))]
vif['Features']= x.columns
vif
# Out:
#        Values                       Features
# 0    1.084911                        Country
# 1    1.631889                         Region
# 2   44.885398                 Happiness Rank
# 3    1.220180                 Standard Error
# 4   12.277578       Economy (GDP per Capita)
# 5    4.661038                         Family
# 6    2.444835       Health (Life Expectancy)
# 7    2.773840                        Freedom
# 8    1.627761  Trust (Government Corruption)
# 9    1.951029                     Generosity
# 10  10.440251              Dystopia Residual

# %%
x.drop('Happiness Rank',axis=1,inplace=True)

# %%
x
# Out:
#       Country    Region  Standard Error  Economy (GDP per Capita)    Family  \
# 0    1.242090  1.289771       -0.926411                  1.378471  1.662198
# 1   -0.421627  1.289771        0.251283                  1.143912  2.023143
# 2   -0.877439  1.289771       -1.007232                  1.201586  1.735733
# 3    0.603952  1.289771       -0.503739                  1.534089  1.541499
# 4   -1.173718 -0.043870       -0.792595                  1.203604  1.488298
# ..        ...       ...             ...                       ...       ...
# 147 -1.720693  0.622951       -1.257050                 -1.302792 -2.018432
# 148  0.877439  0.956361       -0.875825                 -1.546193 -0.944765
# 149 -1.424415  0.956361       -0.698837                 -1.385395 -1.927121
# 150 -1.242090  0.956361        2.129637                 -2.061133 -1.809955
# 151  1.356043  0.956361        1.301698                 -1.579562 -2.289897
#
# ...

# %%
vif=pd.DataFrame()
vif["values"]=[variance_inflation_factor(x.values,i)
              for i in range(len(x.columns))]
vif["Features"]=x.columns
vif
# Out:
#      values                       Features
# 0  1.052021                        Country
# 1  1.332259                         Region
# 2  1.218460                 Standard Error
# 3  2.799501       Economy (GDP per Capita)
# 4  2.225454                         Family
# 5  2.007805       Health (Life Expectancy)
# 6  1.888433                        Freedom
# 7  1.395473  Trust (Government Corruption)
# 8  1.370415                     Generosity
# 9  1.037147              Dystopia Residual

# %%
y.value_counts()
# Out:
# 5.192    2
# 7.587    1
# 4.686    1
# 4.839    1
# 4.800    1
#         ..
# 5.878    1
# 5.855    1
# 5.848    1
# 5.833    1
# 2.839    1
# Name: Happiness Score, Length: 151, dtype: int64

# %%
df1
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0        130       9               1            7.587       -3.378165
# 1         57       9               2            7.561       -3.019206
# 2         37       9               3            7.527       -3.402799
# 3        102       9               4            7.522       -3.249335
# 4         24       5               5            7.427       -3.337378
# ..       ...     ...             ...              ...             ...
# 152        0       7             153            3.575       -3.478943
# 153      114       8             154            3.465       -3.362746
# 154       13       8             155            3.340       -3.308801
# 156       21       8             157            2.905       -2.446686
# 157      135       8             158            2.839       -2.699041
#
#      Economy (GDP per Capita)     Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression

# %%
MaxAcc=0
MaxRS=0
for i in range(0,50):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=i)
    LR=LinearRegression()
    LR.fit(x_train,y_train)
    pred=LR.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>MaxAcc:
        MaxAcc=acc
        MaxRS=i
print('Max Accuracy is:',MaxAcc,'at Random State:',MaxRS)
# Out:
# Max Accuracy is: 0.9943987067393915 at Random State: 4

# %%
df1.dtypes
# Out:
# Country                            int32
# Region                             int32
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=MaxRS)

# %%
LRC=LinearRegression()
LRC.fit(x_test,y_test)
pred_LRC=LR.predict(x_test)
pred_train=LRC.predict(x_train)
print('r2 score:',r2_score(y_test,pred_LRC))
print('r2 Score on Trained data:',r2_score(y_train,pred_train))
print('Mean Absolute Error:',mean_absolute_error(y_test,pred_LRC))
print('Mean Squared Error:',mean_squared_error(y_test,pred_LRC))
print('RMSE:',np.sqrt(y_test,pred_LRC))
# Out:
# r2 score: 0.9942958672291886
# r2 Score on Trained data: 0.9839658436180746
# Mean Absolute Error: 0.06632111578836652
# Mean Squared Error: 0.008579640349144439
# RMSE: 47     2.444381
# 18     2.633819
# 137    1.998750
# 140    1.982675
# 110    2.163562
# 93     2.229574
# 83     2.267157
# 14     2.668145
# 5      2.721397
# 66     2.385162
# 26     2.582634
# 11     2.688122
# 12     2.683282
# 67     2.367488
# 120    2.124618
# 35     2.515750
# 62     2.398750
# 2      2.743538
# 25     2.598076
# 132    2.062038
# 87     2.258761
# 133    2.053777
# 72     2.330021
# 27     2.571186
# 30     2.550490
# 19     2.626975
# 96     2.213143
# 16     2.635527
# 20     2.620496
# 116    2.136586
# 42     2.474470
# 149    1.912067
# 141    1.975854
# 1      2.749727
# 106    2.176924
# 36     2.510378
# 89     2.252332
# 135    2.019158
# 104    2.188150
# 124    2.102142
# 48     2.441311
# 151    1.893938
# 7      2.713669
# 61     2.399792
# 10     2.697777
# 138    1.997248
# ...

# %%
LR=LinearRegression()
LR.fit(x_train,y_train)
predLR=LR.predict(x_test)
pred_train=LR.predict(x_train)
print("r2 score:",r2_score(y_test,predLR))
print("r2 score on train data:",r2_score(y_train,pred_train))
print("Mean absolute Error:",mean_absolute_error(y_test,predLR))
print("Mean squared error:",mean_squared_error(y_test,predLR))
print("Root Mean squared error:",np.sqrt(mean_squared_error(y_test,predLR)))
# Out:
# r2 score: 0.9943987067393915
# r2 score on train data: 0.9864094291519424
# Mean absolute Error: 0.0642043924642007
# Mean squared error: 0.00842495846380387
# Root Mean squared error: 0.0917875724910724

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import Lasso,Ridge
from sklearn.ensemble import GradientBoostingRegressor

# %%
RFR=RandomForestRegressor()
RFR.fit(x_train,y_train)
pred_RFR=RFR.predict(x_test)
pred_RFR_train=RFR.predict(x_train)
print('r2 Score:',r2_score(y_test,pred_RFR))
print('r2 Score on train data:',r2_score(y_train,pred_RFR_train))
print('r2 Score on train data:',r2_score(y_train,pred_train))
print('Mean absolute Error:',mean_absolute_error(y_test,pred_RFR))
print('Mean squared error:',mean_squared_error(y_test,pred_RFR))
print('Root Mean squared Error:',np.sqrt(mean_squared_error(y_test,pred_RFR)))
# Out:
# r2 Score: 0.9263952698055655
# r2 Score on train data: 0.9821876024578715
# r2 Score on train data: 0.9864094291519424
# Mean absolute Error: 0.2839408695652173
# Mean squared error: 0.11070957469565229
# Root Mean squared Error: 0.33273048356838647

# %%
DTR=DecisionTreeRegressor()
DTR.fit(x_train,y_train)
pred_DTR=DTR.predict(x_test)
pred_DTR_train=DTR.predict(x_train)
print('r2 Score:',r2_score(y_test,pred_DTR))
print('r2 Score on train data:',r2_score(y_train,pred_DTR_train))
print('Mean Absilute Error:',mean_absolute_error(y_test,pred_DTR))
print('Mean Squared Error:',mean_squared_error(y_test,pred_DTR))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,pred_DTR)))
# Out:
# r2 Score: 0.761453120298345
# r2 Score on train data: 1.0
# Mean Absilute Error: 0.42684782608695643
# Mean Squared Error: 0.3588006304347825
# Root Mean Squared Error: 0.5989996915147641

# %%
RD=Ridge()
RD.fit(x_train,y_train)
pred_RD=RD.predict(x_test)
pred_RD_train=RD.predict(x_train)
print('r2 Score:',r2_score(y_test,pred_RD))
print('r2 Score on train data:',r2_score(y_train,pred_RD_train))
print('Mean Absolute Error',mean_absolute_error(y_test,pred_RD))
print('Mean squared error:',mean_squared_error(y_test,pred))
print('RMSE:',np.sqrt(mean_squared_error(y_test,pred_RD)))
# Out:
# r2 Score: 0.994307015624355
# r2 Score on train data: 0.98635029129434
# Mean Absolute Error 0.06541504656154658
# Mean squared error: 3.2193754988636334
# RMSE: 0.0925357873579138

# %%
LD=Lasso()
LD.fit(x_test,y_test)
pred_LD=LD.predict(x_test)
print('r2 score:',r2_score(y_test,pred_LD))
print('Mean Absolute Error',mean_absolute_error(y_test,pred_LD))
print('Mean Squared Error:',mean_squared_error(y_test,pred_LD))
print('RMSE:',np.sqrt(mean_squared_error(y_test,pred_LD)))
# Out:
# r2 score: 0.09613088491535837
# Mean Absolute Error 1.0288572280798018
# Mean Squared Error: 1.3595181321529075
# RMSE: 1.1659837615305402

# %%
GBR=GradientBoostingRegressor()
GBR.fit(x_train,y_train)
pred_GBR=GBR.predict(x_test)
pred_GBR_train=GBR.predict(x_train)
print('r2 Score:',r2_score(y_test,pred_GBR))
print('r2 Score on train data:',r2_score(y_train,pred_GBR_train))
print('Mean Absolute Error:',mean_absolute_error(y_test,pred_GBR))
print('Mean squared error:',mean_squared_error(y_test,pred_GBR))
print('RMSE:',np.sqrt(mean_squared_error(y_test,pred_GBR)))
# Out:
# r2 Score: 0.9396847820444856
# r2 Score on train data: 0.9992187959324443
# Mean Absolute Error: 0.24422770693749216
# Mean squared error: 0.09072069294855571
# RMSE: 0.3011987598722075

# %%
knn=KNN()
knn.fit(x_train,y_train)
pred_knn=knn.predict(x_test)
pred_knn_train=knn.predict(x_train)
print('r2 score:',r2_score(y_test,pred_knn))
print('r2 Score on train data:',r2_score(y_train,pred_knn_train))
print('Mean Absolute Error:',mean_absolute_error(y_test,pred_knn))
print('Mean Squared Error:',mean_squared_error(y_test,pred_knn))
print('RMSE:',np.sqrt(mean_squared_error(y_test,pred_knn)))
# Out:
# r2 score: 0.8853543363355459
# r2 Score on train data: 0.887010510736584
# Mean Absolute Error: 0.3329304347826086
# Mean Squared Error: 0.17243963304347823
# RMSE: 0.4152585135111359

# %%
from sklearn.model_selection import cross_val_score

# %%
scoreLR=cross_val_score(LR,x,y,cv=5)
print(scoreLR)
print(scoreLR.mean())
print("Difference Between r2 score and Cross validation Score:",r2_score(y_test,pred_LRC)-(scoreLR.mean()))
# Out:
# [0.90007086 0.76087637 0.49165837 0.33202016 0.74854618]
# 0.6466343873807457
# Difference Between r2 score and Cross validation Score: -7.480851147055882

# %%
scoreRFR=cross_val_score(RFR,x,y,cv=5)
print(scoreRFR)
print(scoreRFR.mean())
print("Diff b/w r2 score and cross val score:",r2_score(y_test,pred_RFR)-(scoreRFR.mean()))
# Out:
# [-9.17950572 -2.02842329 -1.84589465 -3.89189518 -6.00805856]
# -4.590755478969195
# Diff b/w r2 score and cross val score: 5.51715074877476

# %%
scoreDTR=cross_val_score(DTR,x,y,cv=5)
print(scoreDTR)
print(scoreDTR.mean())
print("Diff b/w r2 score and cross val score:",r2_score(y_test,pred_DTR)-(scoreDTR.mean()))
# Out:
# [ -9.05072543 -13.3961721  -12.13653341 -12.7820602   -6.83963373]
# -10.841024974443908
# Diff b/w r2 score and cross val score: 11.602478094742253

# %%
scoreknn=cross_val_score(knn,x,y,cv=5)
print(scoreknn)
print(scoreknn.mean())
print("Diff b/w r2 score and cross val score:",r2_score(y_test,pred_knn)-(scoreknn.mean()))
# Out:
# [-9.94099198 -2.08556128 -5.25593213 -8.11546864 -5.81332447]
# -6.242255699748021
# Diff b/w r2 score and cross val score: 7.127610036083567

# %%
scoreLD=cross_val_score(LD,x,y,cv=5)
print(scoreLD)
print(scoreLD.mean())
print("Diff b/w r2 score and cross val score:",r2_score(y_test,pred_LD)-(scoreLD.mean()))
# Out:
# [-38.91416454 -12.95210859  -0.32979912 -31.90390598 -25.88207287]
# -21.996410220355003
# Diff b/w r2 score and cross val score: 22.09254110527036

# %%
scoreRD=cross_val_score(RD,x,y,cv=5)
print(scoreRD)
print(scoreRD.mean())
print("Diff b/w r2 score and cross val score:",r2_score(y_test,pred_RD)-(scoreRD.mean()))
# Out:
# [0.90069128 0.75295575 0.49218123 0.34395465 0.73424834]
# 0.6448062494237895
# Diff b/w r2 score and cross val score: 0.34950076620056547

# %%
scoreGBR=cross_val_score(GBR,x,y,cv=5)
print(scoreGBR)
print(scoreGBR.mean())
print("Diff b/w r2 score and cross val score:",r2_score(y_test,pred_GBR)-(scoreGBR.mean()))
# Out:
# [-4.18397307 -0.90066033 -2.62863506 -2.36791924 -3.59448827]
# -2.7351351934969808
# Diff b/w r2 score and cross val score: 3.6748199755414666

# %%
#From the difference of both r2 socre and cross validation score computed on r2 score. We are selecting Linear Regression as our best fitting model

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters={'fit_intercept':[1,2,4,5],
           'n_jobs':[2,5,6,9]}

# %%
gscv=GridSearchCV(LR,parameters,cv=2)
gscv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=2, estimator=LinearRegression(),
#              param_grid={'fit_intercept': [1, 2, 4, 5], 'n_jobs': [2, 5, 6, 9]})

# %%
gscv.best_params_
# Out:
# {'fit_intercept': 1, 'n_jobs': 2}

# %%
Model=LinearRegression(fit_intercept=1,n_jobs=2)

# %%
Model.fit(x_train,y_train)
pred=Model.predict(x_test)
print('r2_score:',r2_score(y_test,pred_LRC))
print('Mean Absolute Error:',mean_absolute_error(y_test,pred_LRC))
print('Mean Squared Error:',mean_squared_error(y_test,pred_LRC))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,pred_LRC)))
# Out:
# r2_score: -6.834216759675136
# Mean Absolute Error: 3.2941561444472978
# Mean Squared Error: 11.783519934738745
# Root Mean Squared Error: 3.432713203100245
