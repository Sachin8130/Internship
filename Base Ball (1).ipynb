# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Baseball.csv')

# %%
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
df.shape
# Out:
# (30, 17)

# %% [markdown]
# Data contains 30 rows and 17 columns

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# The data doesn't contain null data

# %%
df.nunique().to_frame('counts')
# Out:
#      counts
# W        24
# R        28
# AB       29
# H        29
# 2B       22
# 3B       23
# HR       27
# BB       29
# SO       29
# SB       27
# RA       30
# ER       30
# ERA      30
# CG        9
# SHO      12
# SV       20
# E        21

# %%
#Visualization

# %%
sns.distplot(df['R'])
# Out:
# <AxesSubplot:xlabel='R', ylabel='Density'>

# %%
sns.distplot(df['AB'])
# Out:
# <AxesSubplot:xlabel='AB', ylabel='Density'>

# %%
sns.distplot(df['H'])
# Out:
# <AxesSubplot:xlabel='H', ylabel='Density'>

# %%
sns.distplot(df['2B'])
# Out:
# <AxesSubplot:xlabel='2B', ylabel='Density'>

# %%
sns.distplot(df['3B'])
# Out:
# <AxesSubplot:xlabel='3B', ylabel='Density'>

# %%
sns.distplot(df['HR'])
# Out:
# <AxesSubplot:xlabel='HR', ylabel='Density'>

# %%
sns.distplot(df['SO'])
# Out:
# <AxesSubplot:xlabel='SO', ylabel='Density'>

# %%
sns.distplot(df['SB'])
# Out:
# <AxesSubplot:xlabel='SB', ylabel='Density'>

# %%
sns.distplot(df['RA'])
# Out:
# <AxesSubplot:xlabel='RA', ylabel='Density'>

# %%
sns.distplot(df['ER'])
# Out:
# <AxesSubplot:xlabel='ER', ylabel='Density'>

# %%
df['W'].value_counts()
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: W, dtype: int64

# %%
sns.countplot(df['W'])
# Out:
# <AxesSubplot:xlabel='W', ylabel='count'>

# %%
plt.figure(figsize=(10,10))
sns.countplot(df['R'])
# Out:
# <AxesSubplot:xlabel='R', ylabel='count'>

# %%
plt.figure(figsize=(10,10))
sns.countplot(df['AB'])
# Out:
# <AxesSubplot:xlabel='AB', ylabel='count'>

# %%
plt.figure(figsize=(10,10))
sns.countplot(df['H'])
# Out:
# <AxesSubplot:xlabel='H', ylabel='count'>

# %%
sns.histplot(df['W'])
# Out:
# <AxesSubplot:xlabel='W', ylabel='Count'>

# %%
sns.histplot(df['R'])
# Out:
# <AxesSubplot:xlabel='R', ylabel='Count'>

# %%
sns.histplot(df['AB'])
# Out:
# <AxesSubplot:xlabel='AB', ylabel='Count'>

# %%
sns.histplot(df['H'])
# Out:
# <AxesSubplot:xlabel='H', ylabel='Count'>

# %%
sns.histplot(df['2B'])
# Out:
# <AxesSubplot:xlabel='2B', ylabel='Count'>

# %%
sns.histplot(df['3B'])
# Out:
# <AxesSubplot:xlabel='3B', ylabel='Count'>

# %%
sns.histplot(df['HR'])
# Out:
# <AxesSubplot:xlabel='HR', ylabel='Count'>

# %%
sns.histplot(df['BB'])
# Out:
# <AxesSubplot:xlabel='BB', ylabel='Count'>

# %%
sns.histplot(df['SO'])
# Out:
# <AxesSubplot:xlabel='SO', ylabel='Count'>

# %%
sns.histplot(df['SB'])
# Out:
# <AxesSubplot:xlabel='SB', ylabel='Count'>

# %%
sns.histplot(df['RA'])
# Out:
# <AxesSubplot:xlabel='RA', ylabel='Count'>

# %%
sns.histplot(df['ER'])
# Out:
# <AxesSubplot:xlabel='ER', ylabel='Count'>

# %%
sns.histplot(df['ERA'])
# Out:
# <AxesSubplot:xlabel='ERA', ylabel='Count'>

# %%
sns.histplot(df['CG'])
# Out:
# <AxesSubplot:xlabel='CG', ylabel='Count'>

# %%
sns.histplot(df['SHO'])
# Out:
# <AxesSubplot:xlabel='SHO', ylabel='Count'>

# %%
sns.histplot(df['SV'])
# Out:
# <AxesSubplot:xlabel='SV', ylabel='Count'>

# %%
sns.histplot(df['E'])
# Out:
# <AxesSubplot:xlabel='E', ylabel='Count'>

# %%
plt.pie(df['ERA'])
# Out:
# ([<matplotlib.patches.Wedge at 0x16e9b679250>,
# ...
#  [Text(1.0946432792703422, 0.10842550967494481, ''),
#   Text(1.0491700892122087, 0.3305179630556352, ''),
#   Text(0.9599891477530517, 0.537048262446095, ''),
#   Text(0.8323723430715491, 0.7191357886307562, ''),
#   Text(0.6481409986728606, 0.8887706373634016, ''),
#   Text(0.4351332600231067, 1.0102767175490404, ''),
#   Text(0.2179359368172156, 1.0781947539492125, ''),
#   Text(-0.015867456406337667, 1.0998855503311211, ''),
#   Text(-0.24071607397918063, 1.0733386100052722, ''),
#   Text(-0.46224689564175453, 0.9981622150079421, ''),
#   Text(-0.6744299585942413, 0.8689903514715053, ''),
#   Text(-0.8384333701813935, 0.7120600282042734, ''),
#   Text(-0.9625368380402123, 0.5324686238789572, ''),
#   Text(-1.0537868456602395, 0.3154889600500197, ''),
#   Text(-1.0972128619999497, 0.07825557783237892, ''),
#   Text(-1.092582247143863, -0.1275305188026254, ''),
#   Text(-1.0574699539567851, -0.30291466864223465, ''),
# ...

# %%
#Bivariate Analysis

# %%
sns.scatterplot(x='W',y='R',hue='W',data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='R'>

# %%
sns.scatterplot(x='W',y='H',hue='W',data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='H'>

# %%
sns.scatterplot(x='W',y='2B',hue='W',data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='2B'>

# %%
sns.scatterplot(x='W',y='3B',hue='W',data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='3B'>

# %%
sns.scatterplot(x='W',y='HR',hue='W',data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='HR'>

# %%
sns.scatterplot(x='W',y='SO',hue='W',data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='SO'>

# %%
sns.scatterplot(x='RA',y='W',hue='W',data=df)
# Out:
# <AxesSubplot:xlabel='RA', ylabel='W'>

# %%
#This plot shows with increase in average run winning percent is decreasing

# %%
sns.scatterplot(x='W',y='ER',hue='W',data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='ER'>

# %%
#This plot shows with increase in earned run winning percent is decreasing

# %%
sns.scatterplot(x='W',y='ERA',hue='W',data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='ERA'>

# %%
#This plot shows with increase in earned run average winning percent is decreasing

# %%
sns.scatterplot(x='W',y='CG',hue='W',data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='CG'>

# %%
#No Particular positive coorelation

# %%
sns.scatterplot(x='W',y='SHO',hue='W',data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='SHO'>

# %%
#When Shutout is b/w 10-12.5 there are maximum wins

# %%
sns.scatterplot(x='W',y='SV',hue='W',data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='SV'>

# %%
#With Increase in SV , Win is also increasing

# %%
sns.lineplot(x='W',y='SV',data=df,linestyle='-')
# Out:
# <AxesSubplot:xlabel='W', ylabel='SV'>

# %%
sns.lineplot(x='W',y='R',data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='R'>

# %%
sns.lineplot(x='W',y='AB',data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='AB'>

# %%
sns.lineplot(x='W',y='H',data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='H'>

# %%
sns.boxplot(x='W',y='R',data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='R'>

# %%
sns.violinplot(x='W',y='R',data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='R'>

# %%
sns.violinplot(x='W',y='RA',data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='RA'>

# %%
#MultiVariate Analysis

# %%
df.plot(kind='box',subplots=True,layout=(2,10))
# Out:
# W         AxesSubplot(0.125,0.53;0.065678x0.35)
# R      AxesSubplot(0.203814,0.53;0.065678x0.35)
# AB     AxesSubplot(0.282627,0.53;0.065678x0.35)
# H      AxesSubplot(0.361441,0.53;0.065678x0.35)
# 2B     AxesSubplot(0.440254,0.53;0.065678x0.35)
# 3B     AxesSubplot(0.519068,0.53;0.065678x0.35)
# HR     AxesSubplot(0.597881,0.53;0.065678x0.35)
# BB     AxesSubplot(0.676695,0.53;0.065678x0.35)
# SO     AxesSubplot(0.755508,0.53;0.065678x0.35)
# SB     AxesSubplot(0.834322,0.53;0.065678x0.35)
# RA        AxesSubplot(0.125,0.11;0.065678x0.35)
# ER     AxesSubplot(0.203814,0.11;0.065678x0.35)
# ERA    AxesSubplot(0.282627,0.11;0.065678x0.35)
# CG     AxesSubplot(0.361441,0.11;0.065678x0.35)
# SHO    AxesSubplot(0.440254,0.11;0.065678x0.35)
# SV     AxesSubplot(0.519068,0.11;0.065678x0.35)
# E      AxesSubplot(0.597881,0.11;0.065678x0.35)
# dtype: object

# %%
df.plot(kind='kde',subplots=True,layout=(4,5))
# Out:
# array([[<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>]], dtype=object)

# %%
plt.figure(figsize=(10,10))
df.plot(kind='box',subplots=True,layout=(2,9))
# Out:
# W         AxesSubplot(0.125,0.53;0.0731132x0.35)
# R      AxesSubplot(0.212736,0.53;0.0731132x0.35)
# AB     AxesSubplot(0.300472,0.53;0.0731132x0.35)
# H      AxesSubplot(0.388208,0.53;0.0731132x0.35)
# 2B     AxesSubplot(0.475943,0.53;0.0731132x0.35)
# 3B     AxesSubplot(0.563679,0.53;0.0731132x0.35)
# HR     AxesSubplot(0.651415,0.53;0.0731132x0.35)
# BB     AxesSubplot(0.739151,0.53;0.0731132x0.35)
# SO     AxesSubplot(0.826887,0.53;0.0731132x0.35)
# SB        AxesSubplot(0.125,0.11;0.0731132x0.35)
# RA     AxesSubplot(0.212736,0.11;0.0731132x0.35)
# ER     AxesSubplot(0.300472,0.11;0.0731132x0.35)
# ERA    AxesSubplot(0.388208,0.11;0.0731132x0.35)
# CG     AxesSubplot(0.475943,0.11;0.0731132x0.35)
# SHO    AxesSubplot(0.563679,0.11;0.0731132x0.35)
# SV     AxesSubplot(0.651415,0.11;0.0731132x0.35)
# E      AxesSubplot(0.739151,0.11;0.0731132x0.35)
# dtype: object

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# '''None of the column have null value'''
# '''In almost all the columns there is a difference between 75% and Max, Hence Outliers in this data might be present'''
# '''Skewness is also present in many columns'''

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %%
from scipy.stats import boxcox

# %%
df['R']=boxcox(df['R'],0)

# %%
df.skew()
# Out:
# W      0.047089
# R      0.744196
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %%
df['R']=boxcox(df['R'],0.5)

# %%
df.skew()
# Out:
# W      0.047089
# R      0.710743
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %%
df['H']=boxcox(df['H'],0)

# %%
df.skew()
# Out:
# W      0.047089
# R      0.710743
# AB     0.183437
# H      0.628554
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %%
df['H']=np.cbrt(df['H'])

# %%
df.skew()
# Out:
# W      0.047089
# R      0.710743
# AB     0.183437
# H      0.624654
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %%
df['HR']=boxcox(df['HR'],0)

# %%
df.skew()
# Out:
# W      0.047089
# R      0.710743
# AB     0.183437
# H      0.624654
# 2B    -0.230650
# 3B     0.129502
# HR    -0.013351
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %%
df['SV']=boxcox(df['SV'],0)

# %%
df.skew()
# Out:
# W      0.047089
# R      0.710743
# AB     0.183437
# H      0.624654
# 2B    -0.230650
# 3B     0.129502
# HR    -0.013351
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.150582
# E      0.890132
# dtype: float64

# %%
df['E']=boxcox(df['E'],0)

# %%
df.skew()
# Out:
# W      0.047089
# R      0.710743
# AB     0.183437
# H      0.624654
# 2B    -0.230650
# 3B     0.129502
# HR    -0.013351
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.150582
# E      0.630080
# dtype: float64

# %%
df['E']=boxcox(df['E'],0)

# %%
df.skew()
# Out:
# W      0.047089
# R      0.710743
# AB     0.183437
# H      0.624654
# 2B    -0.230650
# 3B     0.129502
# HR    -0.013351
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.150582
# E      0.569594
# dtype: float64

# %%
df
# Out:
#       W         R    AB         H   2B  3B        HR   BB    SO   SB   RA  \
# 0    95  3.132170  5575  1.940871  300  42  4.934474  383   973  104  641
# 1    83  3.116776  5467  1.931615  277  44  5.049856  439  1264   70  700
# 2    81  3.101288  5439  1.934606  303  29  4.948760  533  1157   86  640
# 3    76  3.072648  5533  1.933707  260  27  4.912655  404  1231   68  701
# 4    74  3.112824  5605  1.941928  289  49  5.017280  455  1259   83  803
# 5    93  3.212425  5509  1.939859  308  17  5.446737  570  1151   88  670
# 6    87  3.153084  5567  1.934734  272  19  5.356586  554  1227   63  698
# 7    81  3.126200  5485  1.932994  246  20  5.379897  418  1331   44  693
# 8    80  3.086334  5485  1.933836  278  32  5.117994  436  1310   87  642
# 9    78  3.144863  5640  1.940752  294  33  5.081404  478  1148   71  753
# 10   88  3.146418  5511  1.936124  279  32  5.147494  503  1233  101  733
# 11   86  3.134851  5459  1.932537  278  26  5.438079  486  1392  121  618
# ...

# %%
df['E']=np.log(df['E'])

# %%
df.skew()
# Out:
# W      0.047089
# R      0.710743
# AB     0.183437
# H      0.624654
# 2B    -0.230650
# 3B     0.129502
# HR    -0.013351
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.150582
# E      0.529070
# dtype: float64

# %%
df['E']=np.log(df['E'])

# %%
df.skew()
# Out:
# W      0.047089
# R      0.710743
# AB     0.183437
# H      0.624654
# 2B    -0.230650
# 3B     0.129502
# HR    -0.013351
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.150582
# E      0.429458
# dtype: float64

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(df[['R','AB','H','2B','3B','HR','BB','SO','SB','RA','ER','ERA','SV','E']]))
z
# Out:
#            R        AB         H        2B        3B        HR        BB  \
# 0   0.668504  0.847731  1.648031  1.420173  1.041193  0.763654  1.534902
# 1   0.183001  0.711094  0.982661  0.127403  1.235809  0.156480  0.536592
# 2   0.305499  1.115233  0.132556  1.588795  0.223808  0.688477  1.139144
# 3   1.208773  0.241522  0.388003  0.828122  0.418423  0.878472  1.160536
# 4   0.058338  1.280738  1.948476  0.801892  1.722347  0.327905  0.251360
# 5   3.199728  0.104884  1.360636  1.869832  1.391501  1.932027  1.798742
# 6   1.328120  0.732263  0.096292  0.153633  1.196885  1.457625  1.513510
# 7   0.480221  0.451289  0.590703  1.615025  1.099578  1.580295  0.910958
# 8   0.777127  0.451289  0.351338  0.183611  0.068115  0.202082  0.590073
# 9   1.068835  1.785913  1.614405  1.082929  0.165423  0.009537  0.158660
# 10  1.117902  0.076017  0.298907  0.239818  0.068115  0.357323  0.604334
# 11  0.753072  0.826562  0.720622  0.183611  0.515731  1.886465  0.301276
# ...

# %%
threshold=3
np.where(z>3)
# Out:
# (array([5], dtype=int64), array([0], dtype=int64))

# %%
df.plot(kind='box',subplots=True,layout=(4,5),figsize=(10,10))
# Out:
# W         AxesSubplot(0.125,0.712609;0.133621x0.167391)
# R      AxesSubplot(0.285345,0.712609;0.133621x0.167391)
# AB      AxesSubplot(0.44569,0.712609;0.133621x0.167391)
# H      AxesSubplot(0.606034,0.712609;0.133621x0.167391)
# 2B     AxesSubplot(0.766379,0.712609;0.133621x0.167391)
# 3B        AxesSubplot(0.125,0.511739;0.133621x0.167391)
# HR     AxesSubplot(0.285345,0.511739;0.133621x0.167391)
# BB      AxesSubplot(0.44569,0.511739;0.133621x0.167391)
# SO     AxesSubplot(0.606034,0.511739;0.133621x0.167391)
# SB     AxesSubplot(0.766379,0.511739;0.133621x0.167391)
# RA         AxesSubplot(0.125,0.31087;0.133621x0.167391)
# ER      AxesSubplot(0.285345,0.31087;0.133621x0.167391)
# ERA      AxesSubplot(0.44569,0.31087;0.133621x0.167391)
# CG      AxesSubplot(0.606034,0.31087;0.133621x0.167391)
# SHO     AxesSubplot(0.766379,0.31087;0.133621x0.167391)
# SV            AxesSubplot(0.125,0.11;0.133621x0.167391)
# E          AxesSubplot(0.285345,0.11;0.133621x0.167391)
# ...

# %%
z=np.array(z)

# %%
z[5][0]
# Out:
# 3.199727643817015

# %%
df_new=df[(z<3).all(axis=1)]

# %%
df_new.plot(kind='box',subplots=True,layout=(4,5),figsize=(10,10))
# Out:
# W         AxesSubplot(0.125,0.712609;0.133621x0.167391)
# R      AxesSubplot(0.285345,0.712609;0.133621x0.167391)
# AB      AxesSubplot(0.44569,0.712609;0.133621x0.167391)
# H      AxesSubplot(0.606034,0.712609;0.133621x0.167391)
# 2B     AxesSubplot(0.766379,0.712609;0.133621x0.167391)
# 3B        AxesSubplot(0.125,0.511739;0.133621x0.167391)
# HR     AxesSubplot(0.285345,0.511739;0.133621x0.167391)
# BB      AxesSubplot(0.44569,0.511739;0.133621x0.167391)
# SO     AxesSubplot(0.606034,0.511739;0.133621x0.167391)
# SB     AxesSubplot(0.766379,0.511739;0.133621x0.167391)
# RA         AxesSubplot(0.125,0.31087;0.133621x0.167391)
# ER      AxesSubplot(0.285345,0.31087;0.133621x0.167391)
# ERA      AxesSubplot(0.44569,0.31087;0.133621x0.167391)
# CG      AxesSubplot(0.606034,0.31087;0.133621x0.167391)
# SHO     AxesSubplot(0.766379,0.31087;0.133621x0.167391)
# SV            AxesSubplot(0.125,0.11;0.133621x0.167391)
# E          AxesSubplot(0.285345,0.11;0.133621x0.167391)
# ...

# %%
df_new
# Out:
#       W         R    AB         H   2B  3B        HR   BB    SO   SB   RA  \
# 0    95  3.132170  5575  1.940871  300  42  4.934474  383   973  104  641
# 1    83  3.116776  5467  1.931615  277  44  5.049856  439  1264   70  700
# 2    81  3.101288  5439  1.934606  303  29  4.948760  533  1157   86  640
# 3    76  3.072648  5533  1.933707  260  27  4.912655  404  1231   68  701
# 4    74  3.112824  5605  1.941928  289  49  5.017280  455  1259   83  803
# 6    87  3.153084  5567  1.934734  272  19  5.356586  554  1227   63  698
# 7    81  3.126200  5485  1.932994  246  20  5.379897  418  1331   44  693
# 8    80  3.086334  5485  1.933836  278  32  5.117994  436  1310   87  642
# 9    78  3.144863  5640  1.940752  294  33  5.081404  478  1148   71  753
# 10   88  3.146418  5511  1.936124  279  32  5.147494  503  1233  101  733
# 11   86  3.134851  5459  1.932537  278  26  5.438079  486  1392  121  618
# 12   85  3.096569  5417  1.930414  243  21  5.170484  435  1150   52  675
# ...

# %%
df_new.shape
# Out:
# (29, 17)

# %%
df.shape
# Out:
# (30, 17)

# %%
df_newcor=df_new.corr()

# %%
df_newcor
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.400562 -0.085780 -0.021014  0.384886 -0.206737  0.264849
# R    0.400562  1.000000  0.436490  0.425828  0.478401  0.141955  0.625480
# AB  -0.085780  0.436490  1.000000  0.770236  0.490752  0.445604 -0.026257
# H   -0.021014  0.425828  0.770236  1.000000  0.527287  0.579511 -0.195582
# 2B   0.384886  0.478401  0.490752  0.527287  1.000000  0.342419 -0.049617
# 3B  -0.206737  0.141955  0.445604  0.579511  0.342419  1.000000 -0.323543
# HR   0.264849  0.625480 -0.026257 -0.195582 -0.049617 -0.323543  1.000000
# BB   0.447513  0.259561 -0.137850 -0.221721  0.211243 -0.404852  0.344045
# SO   0.156469  0.096460 -0.111243 -0.373429 -0.096772 -0.196586  0.491609
# SB  -0.169503  0.073257  0.373674  0.420406  0.194308  0.483818 -0.158841
# RA  -0.823176 -0.030186  0.315499  0.243548 -0.215196  0.312750 -0.097162
# ER  -0.815308 -0.008898  0.309146  0.279897 -0.224993  0.333731 -0.068461
# ...

# %%
#ERA,RA,ER are highly negatively co-related with the win
#Whereas SHO and SV are highly positively co-related with win

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df_newcor,annot=True,cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
# Win is negatively coorelated with RA,ERAandER
#Win is +vely coorelated with SHO,SV,E,R

# %%
#separating Feature columns and Target columns

# %%
x=df_new.drop('W',axis=1)

# %%
x
# Out:
#            R    AB         H   2B  3B        HR   BB    SO   SB   RA   ER  \
# 0   3.132170  5575  1.940871  300  42  4.934474  383   973  104  641  601
# 1   3.116776  5467  1.931615  277  44  5.049856  439  1264   70  700  653
# 2   3.101288  5439  1.934606  303  29  4.948760  533  1157   86  640  584
# 3   3.072648  5533  1.933707  260  27  4.912655  404  1231   68  701  643
# 4   3.112824  5605  1.941928  289  49  5.017280  455  1259   83  803  746
# 6   3.153084  5567  1.934734  272  19  5.356586  554  1227   63  698  652
# 7   3.126200  5485  1.932994  246  20  5.379897  418  1331   44  693  646
# 8   3.086334  5485  1.933836  278  32  5.117994  436  1310   87  642  604
# 9   3.144863  5640  1.940752  294  33  5.081404  478  1148   71  753  694
# 10  3.146418  5511  1.936124  279  32  5.147494  503  1233  101  733  680
# 11  3.134851  5459  1.932537  278  26  5.438079  486  1392  121  618  572
# 12  3.096569  5417  1.930414  243  21  5.170484  435  1150   52  675  630
# ...

# %%
y=df_new['W']

# %%
y
# Out:
# 0      95
# 1      83
# 2      81
# 3      76
# 4      74
# 6      87
# 7      81
# 8      80
# 9      78
# 10     88
# 11     86
# 12     85
# 13     76
# 14     68
# 15    100
# 16     98
# 17     97
# 18     68
# 19     64
# 20     90
# 21     83
# 22     71
# 23     67
# 24     63
# 25     92
# 26     84
# 27     79
# 28     74
# 29     68
# Name: W, dtype: int64

# %%
x.shape
# Out:
# (29, 16)

# %%
y.shape
# Out:
# (29,)

# %%
#Using VIF to remove Multi Collinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['Values']=[variance_inflation_factor(x.values,i)
              for i in range(len(x.columns))]
vif['Features']=x.columns
vif
# Out:
#            Values Features
# 0   102894.955112        R
# 1    82513.143043       AB
# 2    90035.790358        H
# 3      978.406313       2B
# 4       34.792953       3B
# 5     6544.149564       HR
# 6      241.538948       BB
# 7      426.264319       SO
# 8       27.673559       SB
# 9    18639.344417       RA
# 10  182482.177905       ER
# 11  121767.093355      ERA
# 12       6.745093       CG
# 13      29.742699      SHO
# 14    2803.033660       SV
# 15     578.113278        E

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)

# %%
vif=pd.DataFrame()
vif['Values']=[variance_inflation_factor(x.values,i)
              for i in range(len(x.columns))]
vif['Features']=x.columns
vif
# Out:
#          Values Features
# 0      7.969066        R
# 1     20.858003       AB
# 2     10.622321        H
# 3      3.749801       2B
# 4      3.188030       3B
# 5      9.517022       HR
# 6      3.250522       BB
# 7      2.819351       SO
# 8      2.086958       SB
# 9    210.197086       RA
# 10  2246.826839       ER
# 11  1713.750624      ERA
# 12     3.021932       CG
# 13     3.520729      SHO
# 14     6.676485       SV
# 15     2.091596        E

# %%
x.drop('ER',axis=1,inplace=True)

# %%
vif=pd.DataFrame()
vif['Values']=[variance_inflation_factor(x.values,i)
              for i in range(len(x.columns))]
vif['Features']=x.columns
vif
# Out:
#         Values Features
# 0     6.605205        R
# 1     8.146899       AB
# 2     9.911260        H
# 3     3.392658       2B
# 4     3.092191       3B
# 5     7.551814       HR
# 6     3.250280       BB
# 7     2.735439       SO
# 8     1.859050       SB
# 9   142.901325       RA
# 10  138.839598      ERA
# 11    2.578706       CG
# 12    3.354893      SHO
# 13    2.973145       SV
# 14    2.053794        E

# %%
x.drop('RA',axis=1,inplace=True)

# %%
vif=pd.DataFrame()
vif['Values']=[variance_inflation_factor(x.values,i)
              for i in range(len(x.columns))]
vif['Features']=x.columns
vif
# Out:
#       Values Features
# 0   6.592925        R
# 1   5.263052       AB
# 2   8.558195        H
# 3   3.384894       2B
# 4   3.075718       3B
# 5   6.434823       HR
# 6   2.930577       BB
# 7   2.147148       SO
# 8   1.798911       SB
# 9   4.598126      ERA
# 10  2.578107       CG
# 11  3.125505      SHO
# 12  2.902911       SV
# 13  1.996867        E

# %%
y.value_counts()
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 97     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 95     1
# 98     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 79     1
# Name: W, dtype: int64

# %%
#Now there is no Missing value in our dataset
#Outliers have been removed
#All the varibales are having vif values less then 5
#Skewness is removed
#Outliers are removed
#-Vely coorelated columns are removed

# %%
#Now we will test multiple models and select the best model based on  the findings

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression

# %%
MaxAcc=0
MaxRS=0
for i in range(1,10):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=i)
    GBR=GradientBoostingRegressor()
    GBR.fit(x_train,y_train)
    pred=GBR.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>MaxAcc:
        MaxAcc=acc
        MaxRS=i

# %%
print('MaxAcc=',MaxAcc,'MaxRS=',MaxRS)
# Out:
# MaxAcc= 0.8143788326869169 MaxRS= 1

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=MaxRS)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import Lasso,Ridge

# %%
GBR=GradientBoostingRegressor()
GBR.fit(x_train,y_train)
predGBR=GBR.predict(x_test)
pred_train=GBR.predict(x_train)
print("r2_score:",r2_score(y_test,predGBR))
print("r2 score on train data:",r2_score(y_train,pred_train))
print("MAE:",mean_absolute_error(y_test,predGBR))
print("MSE:",mean_squared_error(y_test,predGBR))
print("RMSE:",np.sqrt(mean_squared_error(y_test,predGBR)))
# Out:
# r2_score: 0.7943870164037833
# r2 score on train data: 0.999999927912795
# MAE: 4.93511357660453
# MSE: 27.460756253628055
# RMSE: 5.240301160584957

# %%
LR=LinearRegression()
LR.fit(x_train,y_train)
predLR=LR.predict(x_test)
pred_train=LR.predict(x_train)
print("r2_score:",r2_score(y_test,predLR))
print("r2 score on train data:",r2_score(y_train,pred_train))
print("MAE:",mean_absolute_error(y_test,predLR))
print("MSE:",mean_squared_error(y_test,predLR))
print("RMSE:",np.sqrt(mean_squared_error(y_test,predLR)))
# Out:
# r2_score: 0.2420774133407071
# r2 score on train data: 0.9907786379150035
# MAE: 9.116265141292644
# MSE: 101.22477212938557
# RMSE: 10.061052237682974

# %%
RFR=RandomForestRegressor()
RFR.fit(x_train,y_train)
predRFR=RFR.predict(x_test)
pred_train=RFR.predict(x_train)
print("r2_score:",r2_score(y_test,predRFR))
print("r2 score on train data:",r2_score(y_train,pred_train))
print("MAE:",mean_absolute_error(y_test,predRFR))
print("MSE:",mean_squared_error(y_test,predRFR))
print("RMSE:",np.sqrt(mean_squared_error(y_test,predRFR)))
# Out:
# r2_score: 0.7140067387687189
# r2 score on train data: 0.9161661363070367
# MAE: 4.9655555555555555
# MSE: 38.19598888888888
# RMSE: 6.180290356357772

# %%
DTR=DecisionTreeRegressor()
DTR.fit(x_train,y_train)
predDTR=DTR.predict(x_test)
pred_train=DTR.predict(x_train)
print("r2_score:",r2_score(y_test,predDTR))
print("r2 score on train data:",r2_score(y_train,pred_train))
print("MAE:",mean_absolute_error(y_test,predDTR))
print("MSE:",mean_squared_error(y_test,predDTR))
print("RMSE:",np.sqrt(mean_squared_error(y_test,predDTR)))
# Out:
# r2_score: 0.742928452579035
# r2 score on train data: 1.0
# MAE: 5.666666666666667
# MSE: 34.333333333333336
# RMSE: 5.8594652770823155

# %%
knn=KNN()
knn.fit(x_train,y_train)
predknn=knn.predict(x_test)
pred_train=knn.predict(x_train)
print("r2_score:",r2_score(y_test,predknn))
print("r2 score on train data:",r2_score(y_train,pred_train))
print("MAE:",mean_absolute_error(y_test,predknn))
print("MSE:",mean_squared_error(y_test,predknn))
print("RMSE:",np.sqrt(mean_squared_error(y_test,predknn)))
# Out:
# r2_score: 0.5979034941763726
# r2 score on train data: 0.4954370624533052
# MAE: 6.022222222222224
# MSE: 53.70222222222223
# RMSE: 7.328180007493145

# %%
Lr=Lasso()
Lr.fit(x_train,y_train)
predLr=Lr.predict(x_test)
pred_train=Lr.predict(x_train)
print("r2_score:",r2_score(y_test,predLr))
print("r2 score on train data:",r2_score(y_train,pred_train))
print("MAE:",mean_absolute_error(y_test,predLr))
print("MSE:",mean_squared_error(y_test,predLr))
print("RMSE:",np.sqrt(mean_squared_error(y_test,predLr)))
# Out:
# r2_score: 0.9422312565042669
# r2 score on train data: 0.850441404842488
# MAE: 2.1915257080341934
# MSE: 7.715336631319025
# RMSE: 2.777649479563436

# %%
RR=Ridge()
RR.fit(x_train,y_train)
predRR=RR.predict(x_test)
pred_train=GBR.predict(x_train)
print("r2_score:",r2_score(y_test,predRR))
print("r2 score on train data:",r2_score(y_train,pred_train))
print("MAE:",mean_absolute_error(y_test,predRR))
print("MSE:",mean_squared_error(y_test,predRR))
print("RMSE:",np.sqrt(mean_squared_error(y_test,predRR)))
# Out:
# r2_score: 0.9110216558562813
# r2 score on train data: 0.999999927912795
# MAE: 3.015818987503998
# MSE: 11.883552184527769
# RMSE: 3.447252846039549

# %%
from sklearn.model_selection import cross_val_score

# %%
scoreLR=cross_val_score(LR,x,y,cv=5)
print(scoreLR)
print(scoreLR.mean())
print("Difference between r2 Score and cross Validation is :",r2_score(y_test,predLR)-(scoreLR.mean()))
# Out:
# [ 0.57767205 -0.59268482  0.71518393  0.49539353  0.70657016]
# 0.3804269696605228
# Difference between r2 Score and cross Validation is : -0.13834955631981571

# %%
scoreRFR=cross_val_score(RFR,x,y,cv=5)
print(scoreRFR)
print(scoreRFR.mean())
print("Difference between r2 score and cross validation score is:", r2_score(y_test,predRFR)-(scoreRFR.mean()))
# Out:
# [ 0.40678886 -4.85449605  0.42308515  0.44520131  0.84413443]
# -0.5470572581803503
# Difference between r2 score and cross validation score is: 1.2610639969490691

# %%
scoreDTR=cross_val_score(DTR,x,y,cv=5)
print(scoreDTR)
print(scoreDTR.mean())
print("Difference between r2 score and cross validation score is:", r2_score(y_test,predDTR)-(scoreDTR.mean()))
# Out:
# [ -1.12045455 -11.34210526   0.11417817   0.39180328   0.12441038]
# -2.366433596886987
# Difference between r2 score and cross validation score is: 3.1093620494660223

# %%
scoreknn=cross_val_score(knn,x,y,cv=5)
print(scoreknn)
print(scoreknn.mean())
print("Difference between r2 score and cross validation score is:", r2_score(y_test,predknn)-(scoreknn.mean()))
# Out:
# [ 0.30059091 -1.84842105  0.40784609  0.29665574  0.77216981]
# -0.014231701002538987
# Difference between r2 score and cross validation score is: 0.6121351951789116

# %%
scoreRR=cross_val_score(RR,x,y,cv=5)
print(scoreRR)
print(scoreRR.mean())
print("Difference between r2 score and cross validation score is:", r2_score(y_test,predRR)-(scoreRR.mean()))
# Out:
# [ 0.61453009 -0.79193926  0.70668444  0.90961803  0.83890486]
# 0.4555596311329014
# Difference between r2 score and cross validation score is: 0.4554620247233799

# %%
scoreLR=cross_val_score(Lr,x,y,cv=5)
print(scoreLR)
print(scoreLR.mean())
print("Difference between r2 score and cross validation score is:", r2_score(y_test,predLr)-(scoreLR.mean()))
# Out:
# [ 0.74024901 -0.70590127  0.78121845  0.79268082  0.87917213]
# 0.4974838281863974
# Difference between r2 score and cross validation score is: 0.44474742831786945

# %%
scoreGBR=cross_val_score(GBR,x,y,cv=5)
print(scoreGBR)
print(scoreGBR.mean())
print("Difference between r2 score and cross validation score is:", r2_score(y_test,predGBR)-(scoreGBR.mean()))
# Out:
# [ 0.11670964 -8.3225836   0.46066277  0.51732506  0.81633498]
# -1.2823102317339115
# Difference between r2 score and cross validation score is: 2.0766972481376946

# %%
#We are selecting Lasso as our best fit model because error is less and Accuracy is more

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters={'alpha':[1],
           'fit_intercept':[True],
           'max_iter':[7],
           'tol':[2],
           'warm_start':[True]}

# %%
gscv=GridSearchCV(Lr,parameters,cv=5)
gscv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [1], 'fit_intercept': [True], 'max_iter': [7],
#                          'tol': [2], 'warm_start': [True]})

# %%
gscv.best_params_
# Out:
# {'alpha': 1,
#  'fit_intercept': True,
#  'max_iter': 7,
#  'tol': 2,
#  'warm_start': True}

# %%
Model=Lasso(alpha=1,fit_intercept=True,max_iter=7,tol=2,warm_start=True)

# %%
Model.fit(x_train,y_train)
pred=Model.predict(x_test)
print("r2 score=",r2_score(y_test,pred))
print("MAE=",mean_absolute_error(y_test,pred))
print("MSE=",mean_squared_error(y_test,pred))
print("RMSE=",np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# r2 score= 0.7608687879140255
# MAE= 4.194192623678977
# MSE= 31.93730188081571
# RMSE= 5.651309749148043

# %%
import joblib

# %%
joblib.dump(Model,'Baseball')
# Out:
# ['Baseball']

# %%
loaded_model=joblib.load('Baseball')
y_pred=loaded_model.predict(x_test)
test_score=r2_score(y_test,y_pred)
print("Test R2 Score=",test_score*100)
# Out:
# Test R2 Score= 76.08687879140254

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],y_test[:]],index=['Predicted','Original'])
conclusion
# Out:
#                     0          1          2          3          4          5  \
# Predicted   94.939051  71.583144  76.144769  91.701417  83.170528  92.174956
# Original   100.000000  71.000000  64.000000  83.000000  84.000000  90.000000
#
#                    6          7          8
# Predicted  74.847797  91.327421  64.773404
# Original   76.000000  86.000000  63.000000
